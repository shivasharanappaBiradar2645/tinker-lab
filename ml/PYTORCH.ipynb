# %%
import torch
import torch.nn as nn
import torch.optim as optim

from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
data = fetch_california_housing()
X = data.data
y = data.target

X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2)

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_val = scaler.transform(X_val)

X_train = torch.tensor(X_train, dtype=torch.float32)
y_train = torch.tensor(y_train, dtype=torch.float32).view(-1,1)

X_val = torch.tensor(X_val, dtype=torch.float32)
y_val = torch.tensor(y_val, dtype=torch.float32).view(-1,1)


model = nn.Linear(8,1)


criterion = nn.MSELoss()


optimizer = optim.Adam(model.parameters(), lr=0.01)

# training loop
for epoch in range(50):

    optimizer.zero_grad()

    pred = model(X_train)

    loss = criterion(pred, y_train)

    loss.backward()

    optimizer.step()

    if epoch % 10 == 0:
        val_pred = model(X_val)
        val_loss = criterion(val_pred, y_val)

        print(epoch, loss.item(), val_loss.item())
# Out:
# 0 6.793937683105469 6.628959655761719
# 10 6.053506374359131 5.938820838928223
# 20 5.425781726837158 5.344030857086182
# 30 4.89884614944458 4.832794189453125
# 40 4.448408603668213 4.389094829559326
